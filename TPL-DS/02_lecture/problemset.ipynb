# %% [markdown]
# # General instructions
#
# - Install the package `Pandas` in your course-specific virtual environment, if you have not done so already.
# - Store the data file `titanic.csv` either in the same directory as the current Jupyter notebook, or in a subdirectory named `data`.
# - Read in the data set 'titanic.csv' as a Pandas DataFrame.
# - Answer the questions below, and other questions that may arise in the process.
#
# Note that the source of the data set is [Encyclopedia Titanica](https://www.encyclopedia-titanica.org/). Several preprocessing steps have been carried out on the raw dataset. Note that there is also a (less complete) variant of the data set available via the Python package `seaborn`.
#
# There may be occasional problems or errors in the data (unplausible, wrong, ...). If you find some error or strange anomaly, then please give me a hint, so that I can further curate the dataset for the future.

# %% [markdown]
# # 1. Traveler type

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic.csv')

# %%
df.columns
# Out:
# Index(['first_name', 'family_name', 'type', 'ticket_number', 'pclass',
#        'departure', 'price', 'survived', 'lifeboat', 'body_no', 'nationality',
#        'gender', 'age', 'marital_status', 'number_relatives_onboard',
#        'home_location', 'destination', 'age_at_death', 'occupation',
#        'department', 'works_for'],
#       dtype='object')

# %%
df.gender
# Out:
# 434     Male
# 221     Male
# 1132    Male
# 2428    Male
# 1       Male
#         ...
# 143     Male
# 505     Male
# 659     Male
# 946     Male
# 60       NaN
# Name: gender, Length: 2474, dtype: object

# %% [markdown]
# How many crew members and how many passengers are recorded in the dataset?

# %%
members = df.groupby('type').count()
members
# Out:
#            first_name  family_name  ticket_number  pclass  departure  price  \
# type
# Crew             1122         1122              0       0       1122      0
# Passenger        1343         1351           1346    1351       1351   1324
#
#            survived  lifeboat  body_no  nationality  gender   age  \
# type
# Crew           1122       172        0         1112    1122  1120
# Passenger      1352       344        0         1333    1350  1325
#
#            marital_status  number_relatives_onboard  home_location  \
# type
# Crew                  929                      1122            906
# Passenger             920                      1352           1216
#
#            destination  age_at_death  occupation  department  works_for
# type
# Crew                 0           691        1122         974       1122
# Passenger          909          1051         728           0         11

# %%
df
# Out:
#                     first_name      family_name       type  ticket_number  \
# 434                Ernest Owen           Abbott       Crew            NaN
# 221             William Thomas           Abrams       Crew            NaN
# 1132               Robert John            Adams       Crew            NaN
# 2428             Percy Snowden            Ahier       Crew            NaN
# 1               Joseph Francis          Akerman       Crew            NaN
# ...                        ...              ...        ...            ...
# 143   Mubārik Sulaymān Abī Āsī            Ḥannā  Passenger         2663.0
# 505                     Mansūr     Ḥannā Al-Hāj  Passenger         2693.0
# 659      Ṭannūs Ḥannā Mu'awwad           Ṭannūs  Passenger         2684.0
# 946                      Ḥannā  Ṭannūs Mu'awwad  Passenger         2681.0
# 60                         NaN              NaN  Passenger            NaN
#
#                     pclass    departure  price  survived lifeboat  body_no  \
# 434                    NaN  Southampton    NaN     False      NaN      NaN
# 221                    NaN  Southampton    NaN     False      NaN      NaN
# 1132                   NaN  Southampton    NaN     False      NaN      NaN
# 2428                   NaN  Southampton    NaN     False      NaN      NaN
# 1                      NaN  Southampton    NaN     False      NaN      NaN
# ...                    ...          ...    ...       ...      ...      ...
# 143   3rd Class Passengers    Cherbourg    7.0      True  boat 15      NaN
# 505   3rd Class Passengers    Cherbourg    7.0     False      NaN      NaN
# 659   3rd Class Passengers    Cherbourg    7.0     False      NaN      NaN
# 946   3rd Class Passengers    Cherbourg    6.0     False      NaN      NaN
# 60                     NaN          NaN    NaN      True      NaN      NaN
#
#       ... gender   age  marital_status number_relatives_onboard  \
# 434   ...   Male  21.0          Single                        1
# 221   ...   Male  34.0         Married                        1
# 1132  ...   Male  26.0          Single                        0
# 2428  ...   Male  20.0          Single                        0
# 1     ...   Male  37.0         Married                        1
# ...   ...    ...   ...             ...                      ...
# 143   ...   Male  27.0          Single                        0
# 505   ...   Male  35.0         Married                        1
# 659   ...   Male  16.0             NaN                        0
# 946   ...   Male  34.0             NaN                        4
# 60    ...    NaN   NaN             NaN                        0
#
#                         home_location  \
# 434   Southampton, Hampshire, England
# 221   Southampton, Hampshire, England
# 1132  Southampton, Hampshire, England
# 2428  Southampton, Hampshire, England
# 1     Southampton, Hampshire, England
# ...                               ...
# 143            Hardīn, Batroun, Syria
# 505                Kafr Mishki, Syria
# 659                               NaN
# 946                               NaN
# 60                                NaN
#
#                                     destination age_at_death  \
# 434                                         NaN         21.0
# 221                                         NaN          NaN
# 1132                                        NaN         26.0
# 2428                                        NaN         20.0
# 1                                           NaN         37.0
# ...                                         ...          ...
# 143   Wilkes Barre, Pennsylvania, United States         66.0
# 505                     Ottawa, Ontario, Canada          NaN
# 659               Columbus, Ohio, United States          NaN
# 946               Columbus, Ohio, United States         34.0
# 60                                          NaN          NaN
#
#                        occupation        department        works_for
# 434         Lounge Pantry Steward  Victualling Crew  White Star Line
# 221                       Fireman  Engineering Crew  White Star Line
# 1132                      Fireman  Engineering Crew  White Star Line
# 2428               Saloon Steward  Victualling Crew  White Star Line
# 1     Assistant Pantryman Steward  Victualling Crew  White Star Line
# ...                           ...               ...              ...
# 143                           NaN               NaN              NaN
# 505                           NaN               NaN              NaN
# 659                       Scholar               NaN              NaN
# 946                        Dealer               NaN              NaN
# 60                            NaN               NaN              NaN
#
# [2474 rows x 21 columns]

# %% [markdown]
# Sort the dataset permanently according to traveler type (crew vs. passenger) and lastname?

# %%
df = df. sort_values(by=['type','family_name'])
df
# Out:
#                     first_name      family_name       type  ticket_number  \
# 434                Ernest Owen           Abbott       Crew            NaN
# 221             William Thomas           Abrams       Crew            NaN
# 1132               Robert John            Adams       Crew            NaN
# 2428             Percy Snowden            Ahier       Crew            NaN
# 1               Joseph Francis          Akerman       Crew            NaN
# ...                        ...              ...        ...            ...
# 143   Mubārik Sulaymān Abī Āsī            Ḥannā  Passenger         2663.0
# 505                     Mansūr     Ḥannā Al-Hāj  Passenger         2693.0
# 659      Ṭannūs Ḥannā Mu'awwad           Ṭannūs  Passenger         2684.0
# 946                      Ḥannā  Ṭannūs Mu'awwad  Passenger         2681.0
# 60                         NaN              NaN  Passenger            NaN
#
#                     pclass    departure  price  survived lifeboat  body_no  \
# 434                    NaN  Southampton    NaN     False      NaN      NaN
# 221                    NaN  Southampton    NaN     False      NaN      NaN
# 1132                   NaN  Southampton    NaN     False      NaN      NaN
# 2428                   NaN  Southampton    NaN     False      NaN      NaN
# 1                      NaN  Southampton    NaN     False      NaN      NaN
# ...                    ...          ...    ...       ...      ...      ...
# 143   3rd Class Passengers    Cherbourg    7.0      True  boat 15      NaN
# 505   3rd Class Passengers    Cherbourg    7.0     False      NaN      NaN
# 659   3rd Class Passengers    Cherbourg    7.0     False      NaN      NaN
# 946   3rd Class Passengers    Cherbourg    6.0     False      NaN      NaN
# 60                     NaN          NaN    NaN      True      NaN      NaN
#
#       ... gender   age  marital_status number_relatives_onboard  \
# 434   ...   Male  21.0          Single                        1
# 221   ...   Male  34.0         Married                        1
# 1132  ...   Male  26.0          Single                        0
# 2428  ...   Male  20.0          Single                        0
# 1     ...   Male  37.0         Married                        1
# ...   ...    ...   ...             ...                      ...
# 143   ...   Male  27.0          Single                        0
# 505   ...   Male  35.0         Married                        1
# 659   ...   Male  16.0             NaN                        0
# 946   ...   Male  34.0             NaN                        4
# 60    ...    NaN   NaN             NaN                        0
#
#                         home_location  \
# 434   Southampton, Hampshire, England
# 221   Southampton, Hampshire, England
# 1132  Southampton, Hampshire, England
# 2428  Southampton, Hampshire, England
# 1     Southampton, Hampshire, England
# ...                               ...
# 143            Hardīn, Batroun, Syria
# 505                Kafr Mishki, Syria
# 659                               NaN
# 946                               NaN
# 60                                NaN
#
#                                     destination age_at_death  \
# 434                                         NaN         21.0
# 221                                         NaN          NaN
# 1132                                        NaN         26.0
# 2428                                        NaN         20.0
# 1                                           NaN         37.0
# ...                                         ...          ...
# 143   Wilkes Barre, Pennsylvania, United States         66.0
# 505                     Ottawa, Ontario, Canada          NaN
# 659               Columbus, Ohio, United States          NaN
# 946               Columbus, Ohio, United States         34.0
# 60                                          NaN          NaN
#
#                        occupation        department        works_for
# 434         Lounge Pantry Steward  Victualling Crew  White Star Line
# 221                       Fireman  Engineering Crew  White Star Line
# 1132                      Fireman  Engineering Crew  White Star Line
# 2428               Saloon Steward  Victualling Crew  White Star Line
# 1     Assistant Pantryman Steward  Victualling Crew  White Star Line
# ...                           ...               ...              ...
# 143                           NaN               NaN              NaN
# 505                           NaN               NaN              NaN
# 659                       Scholar               NaN              NaN
# 946                        Dealer               NaN              NaN
# 60                            NaN               NaN              NaN
#
# [2474 rows x 21 columns]

# %% [markdown]
# How many crew members died?

# %%
df[(df.type=='Crew') & (df.survived==False)].count()[0]
# Out:
# /tmp/ipykernel_1628215/3803879465.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df[(df.type=='Crew') & (df.survived==False)].count()[0]
# np.int64(677)

# %% [markdown]
# # 2. Lifeboats

# %% [markdown]
# Which were the 5 boats that saved the largest number of people?

# %%
df[df['survived']==True].groupby('lifeboat')['survived'].count().sort_values(ascending=False)[:5]
# Out:
# lifeboat
# boat 13    46
# boat 11    44
# boat 15    38
# boat 14    35
# boat 4     34
# Name: survived, dtype: int64

# %% [markdown]
# How many lifeboats were there in total?

# %%
df['lifeboat'].nunique()
# Out:
# 20

# %% [markdown]
# Which lifeboats saved the largest number of male passengers?

# %%
df[(df['survived']==True) & (df['gender']=='Male') ].groupby('lifeboat')['survived'].count().sort_values(ascending=False)
# Out:
# lifeboat
# boat 15    32
# boat 13    30
# boat B     23
# boat 9     20
# boat 5     18
# boat 3     18
# boat 7     16
# boat 11    16
# boat 14    15
# boat 4     12
# boat A     11
# boat 1     10
# boat D     10
# boat 10     8
# boat C      8
# boat 2      7
# boat 16     5
# boat 6      4
# boat 12     3
# boat 8      3
# Name: survived, dtype: int64

# %% [markdown]
# Which lifeboats saved the largest proportion of male adult passengers?

# %% [markdown]
# What was the average number of people saved on lifeboats?

# %% [markdown]
# Which boats saved in particular people from the 1st (2nd, 3rd) class?

# %% [markdown]
# What was the average age of rescued people, by lifeboat?

# %% [markdown]
# What was the (1) average age, and the number of people saved by lifeboat? (Note: Calculate this in one single query)

# %% [markdown]
# # 2. Investigation of ticket prices
#
# The prices are given in British Pounds. 1 British Pound at that time corresponds to 161 US Dollar today. And 1 US Dollar corresponds currently to 0.90 Euro. Please convert the original fares to current day Euros, and store it in a new column.

# %% [markdown]
# Are the prices provided in the data the prices paid by person, or the prices paid by ticket (potentially covering multiple people)? Carry out a detailed data analysis to answer this question.

# %% [markdown]
# What are other interesting patterns related to the prices paid? Freely explore!

# %% [markdown]
# # 3. Freely Explore
