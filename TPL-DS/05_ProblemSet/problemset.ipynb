# %% [markdown]
# # General instructions
# -  In this problemset you will work on four datasets related to the titanic ship accident. Your task is to prepare and structure the data in a way that allows future analysis. The final dataset (it should be a single, tidy data set) may look similar to the one that we work with in previous lectures.
# - There may be multiple ways to link and clean up the data. Decide for yourself what makes sense and justify your choices.
# - If you want to better understand the meaning of certain information, then visit https://www.encyclopedia-titanica.org/. In particular, you may study the information on [passengers](https://www.encyclopedia-titanica.org/titanic-passenger-list/), [crew members](https://www.encyclopedia-titanica.org/titanic-crew-list/) and the description of [recovered bodies](https://www.encyclopedia-titanica.org/description-of-recovered-titanic-bodies.html#135).

# %%
import pandas as pd

# %% [markdown]
# # Exercise 1

# %% [markdown]
# Load the four data sets

# %%
df_bodies = pd.read_csv('bodies.csv',sep=';')
df_crew = pd.read_csv('crew.csv')
df_outcomes = pd.read_csv('outcomes.csv')
df_passengers = pd.read_csv('passengers.csv')

# %%
df_bodies.head()
# Out:
#    BODY_NO  GENDER                                           CLOTHING  \
# 0        1    male  Overcoat, grey; one grey coat; one blue coat; ...
# 1        2    male  Brown tweed coat; white steward's jacket; brow...
# 2        3  female  Grey cloth jacket; red jersey jacket; blue alp...
# 3        4    male  Grey coat with fur on collar and cuffs; brown ...
# 4        5  female  Blue waterproof; black jacket and skirt; pink ...
#
#    ESTIMATED_AGE
# 0            NaN
# 1           24.0
# 2           40.0
# 3            2.0
# 4            NaN

# %%
df_bodies.columns = df_bodies.columns.str.lower()

# %%
df_bodies
# Out:
#      body_no  gender                                           clothing  \
# 0          1    male  Overcoat, grey; one grey coat; one blue coat; ...
# 1          2    male  Brown tweed coat; white steward's jacket; brow...
# 2          3  female  Grey cloth jacket; red jersey jacket; blue alp...
# 3          4    male  Grey coat with fur on collar and cuffs; brown ...
# 4          5  female  Blue waterproof; black jacket and skirt; pink ...
# ..       ...     ...                                                ...
# 325      326    male  Steward's white coat; light checked overalls; ...
# 326      327    male                                                NaN
# 327      328  female  Lace trimmed red and black overdress; black un...
# 328      329    male                                                NaN
# 329      330    male                                                NaN
#
#      estimated_age
# 0              NaN
# 1             24.0
# 2             40.0
# 3              2.0
# 4              NaN
# ..             ...
# 325           50.0
# 326           38.0
# 327           14.0
# 328           38.0
# 329           50.0
#
# [330 rows x 4 columns]

# %%
df_crew.head()
# Out:
#    person_id      first_name family_name    departure       nationality  \
# 0       1420     Ernest Owen      Abbott  Southampton           English
# 1       1421  William Thomas      Abrams  Southampton           English
# 2       1422     Robert John       Adams  Southampton           English
# 3       1423   Percy Snowden       Ahier  Southampton  Channel Islander
# 4       1424   Albert Edward     Akerman  Southampton           English
#
#   gender       age marital_status  birth_date  \
# 0   Male  21 years         Single  1891-01-19
# 1   Male  34 years        Married         NaN
# 2   Male  26 years         Single  1885-06-07
# 3   Male  20 years         Single  1892-01-08
# 4   Male  31 years         Single  1880-11-13
#
#                      home_location             occupation        department  \
# 0  Southampton, Hampshire, England  Lounge Pantry Steward  Victualling Crew
# 1  Southampton, Hampshire, England                Fireman  Engineering Crew
# 2  Southampton, Hampshire, England                Fireman  Engineering Crew
# 3  Southampton, Hampshire, England         Saloon Steward  Victualling Crew
# 4  Southampton, Hampshire, England      3rd Class Steward  Victualling Crew
#
#          works_for
# 0  White Star Line
# 1  White Star Line
# 2  White Star Line
# 3  White Star Line
# 4  White Star Line

# %%
df_outcomes.head()
# Out:
#    person_id lifeboat  body_no  death_date
# 0          1      NaN      NaN  1912-04-15
# 1          2      NaN      NaN  1912-04-15
# 2          3   boat A      NaN  1946-02-18
# 3          4      NaN    190.0  1912-04-15
# 4          5  boat 16      NaN  1969-07-27

# %%
df_passengers.head()
# Out:
#    person_id                     first_name family_name  ticket_number  \
# 0          1                        Anthony      Abbing         5547.0
# 1          2                  Eugene Joseph      Abbott         2673.0
# 2          3                          Rhoda      Abbott         2673.0
# 3          4                Rossmore Edward      Abbott         2673.0
# 4          5  Kalle (Karen) Marie Kristiane    Abelseth       348125.0
#
#                  pclass    departure  price nationality  gender       age  \
# 0  3rd Class Passengers  Southampton    7.0    American    Male  41 years
# 1  3rd Class Passengers  Southampton   20.0    American    Male  13 years
# 2  3rd Class Passengers  Southampton   20.0     English  Female  39 years
# 3  3rd Class Passengers  Southampton   20.0     English    Male  16 years
# 4  3rd Class Passengers  Southampton    7.0   Norwegian  Female  16 years
#
#   marital_status  birth_date                                 home_location  \
# 0         Single  1870-05-11               Cincinnati, Ohio, United States
# 1            NaN  1899-03-31  East Providence, Rhode Island, United States
# 2       Divorced  1873-01-25  East Providence, Rhode Island, United States
# 3         Single  1896-02-21  East Providence, Rhode Island, United States
# 4         Single  1895-09-14                              Sondmore, Norway
#
#                                     destination  occupation works_for
# 0               Cincinnati, Ohio, United States  Blacksmith       NaN
# 1  East Providence, Rhode Island, United States     Scholar       NaN
# 2  East Providence, Rhode Island, United States         NaN       NaN
# 3  East Providence, Rhode Island, United States    Jeweller       NaN
# 4        Los Angeles, California, United States         NaN       NaN

# %% [markdown]
# Study important characteristics of the data (number of rows, column names, first rows, ...)

# %%
df_bodies.shape, df_crew.shape, df_outcomes.shape, df_passengers.shape
# Out:
# ((330, 4), (1122, 13), (2541, 4), (1419, 16))

# %%
df_crew.columns, df_bodies.columns, df_outcomes.columns, df_passengers.columns
# Out:
# (Index(['person_id', 'first_name', 'family_name', 'departure', 'nationality',
#         'gender', 'age', 'marital_status', 'birth_date', 'home_location',
#         'occupation', 'department', 'works_for'],
#        dtype='object'),
#  Index(['BODY_NO', 'GENDER', 'CLOTHING', 'ESTIMATED_AGE'], dtype='object'),
#  Index(['person_id', 'lifeboat', 'body_no', 'death_date'], dtype='object'),
#  Index(['person_id', 'first_name', 'family_name', 'ticket_number', 'pclass',
#         'departure', 'price', 'nationality', 'gender', 'age', 'marital_status',
#         'birth_date', 'home_location', 'destination', 'occupation',
#         'works_for'],
#        dtype='object'))

# %% [markdown]
# Briefly describe: (1) How are the four tables related with each other

# %% [markdown]
# #### they have keys which could be combined together to get one whole data they represent differe info about one common topic

# %% [markdown]
# Briefly describe: Do you observe any potential problems or noteworthy characteristics that need further inspection/handling?

# %% [markdown]
# #### Answer
#
#
# * Standartization of columns by type Numerical / String must differ
# * splitting text columns to give more readable and atomized nature
# * Remove Nan, Merge Dataframes into  one
# * Processing datetime mining and correcting

# %% [markdown]
# # Exercise 2

# %% [markdown]
# Your task is to create a single, combined dataset suitable for data analysis. When developing your strategy, you may think about the following questions:
# - Should some datasets be merged (column-wise)?
# - If so, on which keys and using which merge types?
# - Should some datasets be concatenated (row-wise)?
# - Should some datasets be reshaped (pivoted or melted)?
#
# Implement you chosen strategy.

# %%
onboard = pd.concat([df_passengers,df_crew])
onboard.head()
onboard.shape
# Out:
# (2541, 17)

# %%
onboard.head()
# Out:
#    person_id                     first_name family_name  ticket_number  \
# 0          1                        Anthony      Abbing         5547.0
# 1          2                  Eugene Joseph      Abbott         2673.0
# 2          3                          Rhoda      Abbott         2673.0
# 3          4                Rossmore Edward      Abbott         2673.0
# 4          5  Kalle (Karen) Marie Kristiane    Abelseth       348125.0
#
#                  pclass    departure  price nationality  gender       age  \
# 0  3rd Class Passengers  Southampton    7.0    American    Male  41 years
# 1  3rd Class Passengers  Southampton   20.0    American    Male  13 years
# 2  3rd Class Passengers  Southampton   20.0     English  Female  39 years
# 3  3rd Class Passengers  Southampton   20.0     English    Male  16 years
# 4  3rd Class Passengers  Southampton    7.0   Norwegian  Female  16 years
#
#   marital_status  birth_date                                 home_location  \
# 0         Single  1870-05-11               Cincinnati, Ohio, United States
# 1            NaN  1899-03-31  East Providence, Rhode Island, United States
# 2       Divorced  1873-01-25  East Providence, Rhode Island, United States
# 3         Single  1896-02-21  East Providence, Rhode Island, United States
# 4         Single  1895-09-14                              Sondmore, Norway
#
#                                     destination  occupation works_for  \
# 0               Cincinnati, Ohio, United States  Blacksmith       NaN
# 1  East Providence, Rhode Island, United States     Scholar       NaN
# 2  East Providence, Rhode Island, United States         NaN       NaN
# 3  East Providence, Rhode Island, United States    Jeweller       NaN
# 4        Los Angeles, California, United States         NaN       NaN
#
#   department
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
total_board_info = onboard.merge(df_outcomes, on='person_id', how='left')
total_board_info.head(), total_board_info.shape
# Out:
# (   person_id                     first_name family_name  ticket_number  \
#  0          1                        Anthony      Abbing         5547.0
#  1          2                  Eugene Joseph      Abbott         2673.0
#  2          3                          Rhoda      Abbott         2673.0
#  3          4                Rossmore Edward      Abbott         2673.0
#  4          5  Kalle (Karen) Marie Kristiane    Abelseth       348125.0
#
#                   pclass    departure  price nationality  gender       age  \
#  0  3rd Class Passengers  Southampton    7.0    American    Male  41 years
#  1  3rd Class Passengers  Southampton   20.0    American    Male  13 years
#  2  3rd Class Passengers  Southampton   20.0     English  Female  39 years
#  3  3rd Class Passengers  Southampton   20.0     English    Male  16 years
#  4  3rd Class Passengers  Southampton    7.0   Norwegian  Female  16 years
#
#    marital_status  birth_date                                 home_location  \
#  0         Single  1870-05-11               Cincinnati, Ohio, United States
#  1            NaN  1899-03-31  East Providence, Rhode Island, United States
#  2       Divorced  1873-01-25  East Providence, Rhode Island, United States
#  3         Single  1896-02-21  East Providence, Rhode Island, United States
#  4         Single  1895-09-14                              Sondmore, Norway
#
#                                      destination  occupation works_for  \
#  0               Cincinnati, Ohio, United States  Blacksmith       NaN
#  1  East Providence, Rhode Island, United States     Scholar       NaN
#  2  East Providence, Rhode Island, United States         NaN       NaN
#  3  East Providence, Rhode Island, United States    Jeweller       NaN
#  4        Los Angeles, California, United States         NaN       NaN
#
#    department lifeboat  body_no  death_date
#  0        NaN      NaN      NaN  1912-04-15
#  1        NaN      NaN      NaN  1912-04-15
#  2        NaN   boat A      NaN  1946-02-18
#  3        NaN      NaN    190.0  1912-04-15
#  4        NaN  boat 16      NaN  1969-07-27  ,
#  (2541, 20))

# %%
total_board_info
# Out:
#       person_id                     first_name     family_name  ticket_number  \
# 0             1                        Anthony          Abbing         5547.0
# 1             2                  Eugene Joseph          Abbott         2673.0
# 2             3                          Rhoda          Abbott         2673.0
# 3             4                Rossmore Edward          Abbott         2673.0
# 4             5  Kalle (Karen) Marie Kristiane        Abelseth       348125.0
# ...         ...                            ...             ...            ...
# 2536       2537                          Harry        Yearsley            NaN
# 2537       2538                  Francis James           Young            NaN
# 2538       2539                          Mario         Zanetti            NaN
# 2539       2540                       Leopoldo       Zarracchi            NaN
# 2540       2541                Wessel Adrianus  van der Brugge            NaN
#
#                     pclass    departure  price nationality  gender       age  \
# 0     3rd Class Passengers  Southampton    7.0    American    Male  41 years
# 1     3rd Class Passengers  Southampton   20.0    American    Male  13 years
# 2     3rd Class Passengers  Southampton   20.0     English  Female  39 years
# 3     3rd Class Passengers  Southampton   20.0     English    Male  16 years
# 4     3rd Class Passengers  Southampton    7.0   Norwegian  Female  16 years
# ...                    ...          ...    ...         ...     ...       ...
# 2536                   NaN  Southampton    NaN     English    Male  40 years
# 2537                   NaN  Southampton    NaN     English    Male  32 years
# 2538                   NaN  Southampton    NaN       Swiss    Male  20 years
# 2539                   NaN  Southampton    NaN     Italian    Male  24 years
# 2540                   NaN  Southampton    NaN       Dutch    Male  38 years
#
#      marital_status  birth_date                                 home_location  \
# 0            Single  1870-05-11               Cincinnati, Ohio, United States
# 1               NaN  1899-03-31  East Providence, Rhode Island, United States
# 2          Divorced  1873-01-25  East Providence, Rhode Island, United States
# 3            Single  1896-02-21  East Providence, Rhode Island, United States
# 4            Single  1895-09-14                              Sondmore, Norway
# ...             ...         ...                                           ...
# 2536        Married  1871-12-03               Southampton, Hampshire, England
# 2537        Married  1879-11-14               Southampton, Hampshire, England
# 2538         Single  1892-01-09                               London, England
# 2539         Single         NaN               Southampton, Hampshire, England
# 2540         Single  1873-10-17               Southampton, Hampshire, England
#
#                                        destination  \
# 0                  Cincinnati, Ohio, United States
# 1     East Providence, Rhode Island, United States
# 2     East Providence, Rhode Island, United States
# 3     East Providence, Rhode Island, United States
# 4           Los Angeles, California, United States
# ...                                            ...
# 2536                                           NaN
# 2537                                           NaN
# 2538                                           NaN
# 2539                                           NaN
# 2540                                           NaN
#
#                       occupation        works_for        department lifeboat  \
# 0                     Blacksmith              NaN               NaN      NaN
# 1                        Scholar              NaN               NaN      NaN
# 2                            NaN              NaN               NaN   boat A
# 3                       Jeweller              NaN               NaN      NaN
# 4                            NaN              NaN               NaN  boat 16
# ...                          ...              ...               ...      ...
# 2536  First class saloon steward  White Star Line  Victualling Crew      NaN
# 2537                     Fireman  White Star Line  Engineering Crew      NaN
# 2538            Assistant Waiter  White Star Line               NaN      NaN
# 2539                 Wine Butler  White Star Line               NaN      NaN
# 2540                     Fireman  White Star Line  Engineering Crew      NaN
#
#       body_no  death_date
# 0         NaN  1912-04-15
# 1         NaN  1912-04-15
# 2         NaN  1946-02-18
# 3       190.0  1912-04-15
# 4         NaN  1969-07-27
# ...       ...         ...
# 2536      NaN  1939-11-18
# 2537      NaN  1912-04-15
# 2538      NaN  1912-04-15
# 2539      NaN  1912-04-15
# 2540      NaN  1912-04-15
#
# [2541 rows x 20 columns]

# %%
total_board_info_merged = pd.merge(left=total_board_info, right=df_bodies, on='body_no', how='outer')

# %%
total_board_info_merged.shape
# Out:
# (2730, 23)

# %%
total_board_info_merged.isna().sum()
# Out:
# person_id            0
# first_name           9
# family_name          1
# ticket_number     1128
# pclass            1123
# departure            1
# price             1151
# nationality         29
# gender_x             2
# age                 31
# marital_status     647
# birth_date         675
# home_location      360
# destination       1586
# occupation         652
# works_for         1407
# department        1567
# lifeboat          2006
# body_no           2394
# death_date         211
# gender_y          2398
# clothing          2405
# estimated_age     2408
# dtype: int64

# %% [markdown]
# # Exercise 3

# %% [markdown]
# Derive a boolean column that indicates whether a person (crew or passenger) survived the accident or not

# %% [markdown]
# Derive a new column `pclass_no` with numeric values 1, 2, and 3 corresponding to the three passenger classes given in column `pclass`.

# %% [markdown]
# Calculate the age of a person at death and store it in a new column

# %% [markdown]
# Derive a new column `home_country` from the column `home_location`, extracting only the country name from the string

# %% [markdown]
# Which further data cleaning/processing steps would be needed/desirable?
