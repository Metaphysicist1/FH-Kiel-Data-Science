# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exercise 1.1

# %%
v1=np.array([1,0,0])
v2=np.array([0,1,0])
v3=np.array([0,0,1])

# %%
V = 1*v1 + 2*v2 + 3*v3    
print(V)
# Out:
# [1 2 3]

# %% [markdown]
# ### Exercise 1.2

# %%
A = np.array([[1,0,1],[2,1,1],[3,1,1]])

# %%
for vector in A:
    vector = vector[0] * v1 + vector[1] * v2 + vector[2] * v3
    print(vector)
# // ... existing code ...
# Out:
# [1 0 1]
# [2 1 1]
# [3 1 1]

# %% [markdown]
# ### Exercise 1.3

# %%
# // ... existing code ...
A = np.array([[1,0,1],[2,1,1],[3,1,1]])

# Create a 3D plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

# Plot the basis vectors
ax.quiver(0, 0, 0, v1[0], v1[1], v1[2], color='r', label='v1', arrow_length_ratio=0.1)
ax.quiver(0, 0, 0, v2[0], v2[1], v2[2], color='g', label='v2', arrow_length_ratio=0.1)
ax.quiver(0, 0, 0, v3[0], v3[1], v3[2], color='b', label='v3', arrow_length_ratio=0.1)

# Plot the combined vector V
ax.quiver(0, 0, 0, V[0], V[1], V[2], color='purple', label='V = v1 + 2v2 + 3v3', arrow_length_ratio=0.1)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Vector Visualization')

# Set the same scale for all axes
ax.set_box_aspect([1,1,1])

# Add legend
ax.legend()

# Set axis limits
ax.set_xlim([-1, 4])
ax.set_ylim([-1, 4])
ax.set_zlim([-1, 4])

plt.show()
