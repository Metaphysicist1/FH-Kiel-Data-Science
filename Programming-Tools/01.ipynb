# %%
import numpy as np

# %%
val = np.arange(10,10)

# %%
x = np.ndarray((10,10))

# %%
x
# Out:
# array([[5.29625145e-315, 0.00000000e+000, 0.00000000e+000,
#         4.77433420e-317, 4.64421707e-322, 4.83644023e-317,
#         4.83649556e-317, 4.83651928e-317, 4.83654695e-317,
#         4.83657461e-317],
#        [4.83662600e-317, 4.83664971e-317, 4.83676829e-317,
#         4.83682362e-317, 4.83693429e-317, 4.83696196e-317,
#         4.83716354e-317, 4.83719121e-317, 4.83728212e-317,
#         4.83730583e-317],
#        [4.83733350e-317, 4.83736117e-317, 4.83744417e-317,
#         4.83746788e-317, 4.83751927e-317, 4.83754693e-317,
#         4.83757065e-317, 4.83762598e-317, 4.83765365e-317,
#         4.83768132e-317],
#        [4.83773666e-317, 4.83776037e-317, 4.83778409e-317,
#         4.83781175e-317, 4.83787104e-317, 4.83798566e-317,
#         4.83800938e-317, 4.83803705e-317, 4.83806472e-317,
#         4.83809238e-317],
#        [4.83812005e-317, 4.83814772e-317, 4.83817539e-317,
#         4.83823072e-317, 4.83825839e-317, 4.83828606e-317,
# ...

# %%
x[:,4]
# Out:
# array([4.6442171e-322, 4.8369343e-317, 4.8375193e-317, 4.8378710e-317,
#        4.8382584e-317, 4.8385944e-317, 4.8389936e-317, 4.8395192e-317,
#        4.8398789e-317, 4.8403177e-317])
